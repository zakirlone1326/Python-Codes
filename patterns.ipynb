# %%
#drawing square
n = 5
for i in range(n):
    for j in range(n):
        print(" * ", end="")
    print()
# Out:
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *

# %%
#drawing right triangle
n = 5
for i in range(n):
    for j in range(i+1):
        print(" * ", end="")
    print()
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *

# %%
#decreasing triangle
n = 5
for i in range(n):
    for j in range(i,n):
        print(" * ", end="")
    print()
# Out:
#  *  *  *  *  *
#  *  *  *  *
#  *  *  *
#  *  *
#  *

# %%
#right sided triangle
n = 5
for i in range(n):
    for j in range(i,n):
        print(" ",end=" ")
    for j in range(i+1):
        print(" * ", end=" ")
    print()
# Out:
#            *
#          *   *
#        *   *   *
#      *   *   *   *
#    *   *   *   *   *
