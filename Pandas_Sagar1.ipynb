# %%
mca = {
    "Name": ["zakir", "irfan", "ishtiyaq", "salim", "inam"],
    "Roll No": [11, 6, 21, 7, 3 ],
    "District": ["kupwara", "Baramulla", "Bandipora", "Rafiabad", "Sopore"]
}

# %%
print (mca)
# Out:
# {'Name': ['zakir', 'irfan', 'ishtiyaq', 'salim', 'inam'], 'Roll No': [11, 6, 21, 7, 3], 'District': ['kupwara', 'Baramulla', 'Bandipora', 'Rafiabad', 'Sopore']}

# %%
import pandas as pd
df = pd.DataFrame(mca)
print (df)
# Out:
#        Name  Roll No   District
# 0     zakir       11    kupwara
# 1     irfan        6  Baramulla
# 2  ishtiyaq       21  Bandipora
# 3     salim        7   Rafiabad
# 4      inam        3     Sopore

# %%
df.to_csv("mca students.csv", index= False)

# %%
print (df.head(3))
# Out:
#        Name  Roll No   District
# 0     zakir       11    kupwara
# 1     irfan        6  Baramulla
# 2  ishtiyaq       21  Bandipora

# %%
print(df.tail(2))
# Out:
#     Name  Roll No  District
# 3  salim        7  Rafiabad
# 4   inam        3    Sopore

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   Roll No   5 non-null      int64
#  2   District  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %%
print (df.describe)
# Out:
# <bound method NDFrame.describe of        Name  Roll No   District
# 0     zakir       11    kupwara
# 1     irfan        6  Baramulla
# 2  ishtiyaq       21  Bandipora
# 3     salim        7   Rafiabad
# 4      inam        3     Sopore>

# %%
print(df.columns)
# Out:
# Index(['Name', 'Roll No', 'District'], dtype='object')

# %%
print(df.max())
print(df.min())
print(df.shape)
# Out:
# Name          zakir
# Roll No          21
# District    kupwara
# dtype: object
# Name             inam
# Roll No             3
# District    Bandipora
# dtype: object
# (5, 3)

# %%
print(df.loc[2])
print(df.iloc[0:2])
# Out:
# Name         ishtiyaq
# Roll No            21
# District    Bandipora
# Name: 2, dtype: object
#     Name  Roll No   District
# 0  zakir       11    kupwara
# 1  irfan        6  Baramulla

# %%
print(df["Name"])
print()
print(df[["Name", "Roll No"]])
# Out:
# 0       zakir
# 1       irfan
# 2    ishtiyaq
# 3       salim
# 4        inam
# Name: Name, dtype: object
#
#        Name  Roll No
# 0     zakir       11
# 1     irfan        6
# 2  ishtiyaq       21
# 3     salim        7
# 4      inam        3

# %%
# print(df[(df["Roll No"]>3)& (df["Roll No"]<25)])
print(df[(df["Name"] == "zakir")| (df["Name"] == "irfan")])
# Out:
#     Name  Roll No   District
# 0  zakir       11    kupwara
# 1  irfan        6  Baramulla

# %%
fd = pd.read_csv("mca students")
print(fd)
# Out:
#    Unnamed: 0      Name  Roll No   District
# 0           0     zakir       11    kupwara
# 1           1     irfan        6  Baramulla
# 2           2  ishtiyaq       21  Bandipora
# 3           3     salim        7   Rafiabad
# 4           4      inam        3     Sopore
